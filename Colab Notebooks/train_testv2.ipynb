# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# !cp drive/MyDrive/"Colab Notebooks"/replay_buffer_v2.py .
# !cp drive/MyDrive/"Colab Notebooks"/segment_tree.py .
# !cp drive/MyDrive/"Colab Notebooks"/datasampler.py .
# !cp drive/MyDrive/"Colab Notebooks"/critic.py .
# !cp drive/MyDrive/"Colab Notebooks"/model_fc.py .
# !cp drive/MyDrive/"Colab Notebooks"/model_cnn.py .
# !cp drive/MyDrive/"Colab Notebooks"/attacks.py .
# !cp drive/MyDrive/"Colab Notebooks"/linearschedule.py .
# !cp drive/MyDrive/"Colab Notebooks"/datasampler.py .

# %%
# !cp drive/MyDrive/"Colab Notebooks"/test.py .
# !cp drive/MyDrive/"Colab Notebooks"/train.py .

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD GNA GTA --useminimax True --adv RANDOM --eps 0.15 --eps_step 0.05 --k 10
# Out:
# ...
# 9920512it [00:00, 29526404.87it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 32768it [00:00, 355096.29it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# ...
# 1654784it [00:00, 8266674.87it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 8192it [00:00, 103138.73it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
# ...

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD GTA GNA --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD GTA GNA --use_critic True --bs_replaybuffer 640 --best_size=128 --epochs 20
# Out:
# Model number: 210114_29
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GTA GNA --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD GTA GNA --use_critic True --bs_replaybuffer 640 --best_size=128 --epochs 20
# Out:
# Model number: 210114_24
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 166.52, Test Loss: [124.31744851074218, 123.33731320800781, 121.52955073242188, 152.63292243652344, 124.05843503417968]
# ...

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD GNA GTA --useminimax True --adv GNA --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True
# Out:
# Model number: 210114_26
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 152.30, Test Loss: [96.02417087402344, 95.04690485839843, 95.09976174316407, 96.33135395507813, 200.3901221191406]
# Epoch 1, Train Loss: 88.74, Test Loss: [78.08024986572265, 76.18214990234375, 77.51923013916016, 78.96752769775391, 264.45573950195313]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GTA GNA --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD GTA GNA
# Out:
# Model number: 210114_13
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 154.41, Test Loss: [108.60351497802735, 107.627523046875, 106.14517364501953, 147.77854221191407, 108.37996593017579]
# Epoch 1, Train Loss: 111.70, Test Loss: [93.75566733398438, 92.39223442382813, 90.55680247802735, 142.3621030517578, 93.10854382324219]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GTA GNA --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD GTA GNA --epochs 20
# Out:
# Model number: 210114_21
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 154.41, Test Loss: [108.60351497802735, 107.627523046875, 106.14517364501953, 147.77854221191407, 108.37996593017579]
# Epoch 1, Train Loss: 111.70, Test Loss: [93.75566733398438, 92.39223442382813, 90.55680247802735, 142.3621030517578, 93.10854382324219]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GTA GNA --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv GTA GNA
# Out:
# Model number: 210114_18
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 164.65, Test Loss: [115.73733212890625, 114.54622491455078, 114.00798952636718, 146.79606673583984, 115.90190167236328]
# ...

# %%
# !python train.py --model fc --metric_valid original
# Out:
# ['/content', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions']
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 136.76, Test Loss: [90.04316407470704]
# Epoch 1, Train Loss: 82.73, Test Loss: [79.48220035400391]
# Epoch 2, Train Loss: 76.47, Test Loss: [75.7159734375]
# Epoch 3, Train Loss: 73.76, Test Loss: [73.65477257080079]
# Epoch 4, Train Loss: 72.01, Test Loss: [72.24848790283203]
# Epoch 5, Train Loss: 70.78, Test Loss: [71.29288302001953]
# Epoch 6, Train Loss: 69.80, Test Loss: [70.5514437133789]
# Epoch 7, Train Loss: 69.04, Test Loss: [69.90383272705078]
# Epoch 8, Train Loss: 68.42, Test Loss: [69.39686713867188]
# ...

# %%
# !python train.py --model fc --metric_valid original --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 770.98, Test Loss: [70.14564916992188]
# Epoch 1, Train Loss: 650.75, Test Loss: [68.3914201538086]
# Epoch 2, Train Loss: 635.53, Test Loss: [67.81290876464844]
# Epoch 3, Train Loss: 627.92, Test Loss: [67.50499139404297]
# Traceback (most recent call last):
#   File "train.py", line 475, in <module>
#     main()
#   File "train.py", line 434, in main
#     train_loss = train()
#   File "train.py", line 240, in train
#     loss.backward()
#   File "/usr/local/lib/python3.6/dist-packages/torch/tensor.py", line 221, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py", line 132, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# ...

# %%
# !python train.py --model fc --metric_valid original --useminimax True --adv PGD --eps 0.15 --eps_step 0.05 --k 10
# Out:
# Model number: 210109_3
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 132.60, Test Loss: [157.8971921875]
# Epoch 1, Train Loss: 80.83, Test Loss: [145.08932131347657]
# Epoch 2, Train Loss: 75.56, Test Loss: [132.58707443847655]
# Epoch 3, Train Loss: 73.08, Test Loss: [121.84517111816406]
# Epoch 4, Train Loss: 71.43, Test Loss: [116.0330318359375]
# Epoch 5, Train Loss: 70.23, Test Loss: [102.53357846679687]
# Epoch 6, Train Loss: 69.32, Test Loss: [97.15876507568359]
# Epoch 7, Train Loss: 68.58, Test Loss: [91.54434859619141]
# Epoch 8, Train Loss: 67.97, Test Loss: [89.54067459716796]
# Epoch 9, Train Loss: 67.45, Test Loss: [86.37115021972656]

# %%
# !python train.py --model cnn --metric_valid original --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 148.60, Test Loss: [93.77455745849609]
# Epoch 1, Train Loss: 80.99, Test Loss: [77.35110104980468]
# Epoch 2, Train Loss: 70.74, Test Loss: [71.88822230224609]
# Epoch 3, Train Loss: 67.24, Test Loss: [69.25070559082032]
# Epoch 4, Train Loss: 65.61, Test Loss: [68.27099471435547]
# Epoch 5, Train Loss: 64.60, Test Loss: [67.37592735595703]
# Epoch 6, Train Loss: 63.83, Test Loss: [66.9169515258789]
# Epoch 7, Train Loss: 63.24, Test Loss: [66.16143344726562]
# Epoch 8, Train Loss: 62.76, Test Loss: [66.21954986572266]
# Epoch 9, Train Loss: 62.37, Test Loss: [66.15285329589844]

# %%
# !cp drive/MyDrive/"Colab Notebooks"/test.py .
# !cp drive/MyDrive/"Colab Notebooks"/train.py .

# %%
# !python train.py --model fc --metric_valid original --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD --use_critic True

# %%
# !python train.py --model fc --metric_valid original --adv LatentA
# Out:
# ...
# 9920512it [00:01, 9905826.74it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 32768it [00:00, 133540.89it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# ...
# 1654784it [00:00, 2560028.43it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 8192it [00:00, 21482.52it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
# ...

# %%
# !python train.py --model fc --metric_valid original --adv VAEA

# %%
# !python test.py --model fc --metric_test VAEA

# %%
# !cp drive/MyDrive/"Colab Notebooks"/replay_buffer_v2.py .
# !cp drive/MyDrive/"Colab Notebooks"/segment_tree.py .
# !cp drive/MyDrive/"Colab Notebooks"/datasampler.py .
# !cp drive/MyDrive/"Colab Notebooks"/critic.py .
# !cp drive/MyDrive/"Colab Notebooks"/model_fc.py .
# !cp drive/MyDrive/"Colab Notebooks"/model_cnn.py .
# !cp drive/MyDrive/"Colab Notebooks"/attacks.py .
# !cp drive/MyDrive/"Colab Notebooks"/linearschedule.py .
# !cp drive/MyDrive/"Colab Notebooks"/datasampler.py .

# %%
# !python train.py --model fc --metric_valid original --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True
# Out:
# Model number: 210109_0
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 135.25, Test Loss: [88.53926763916016]
# Epoch 1, Train Loss: 84.71, Test Loss: [79.59539763183594]
# Epoch 2, Train Loss: 79.12, Test Loss: [76.44722186279297]
# Epoch 3, Train Loss: 76.35, Test Loss: [74.68481617431641]
# Epoch 4, Train Loss: 74.61, Test Loss: [73.22825924072265]
# Epoch 5, Train Loss: 73.37, Test Loss: [72.37361649169922]
# Epoch 6, Train Loss: 72.47, Test Loss: [71.67882700195312]
# Epoch 7, Train Loss: 71.76, Test Loss: [71.25112492675781]
# Epoch 8, Train Loss: 71.18, Test Loss: [70.92852966308594]
# ...

# %%
# !python train.py --model fc --metric_valid original --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True

# %%
# !python train.py --model fc --metric_valid original --useminimax True --ad