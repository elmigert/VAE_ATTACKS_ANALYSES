# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# !cp drive/MyDrive/"Colab Notebooks"/replay_buffer_v2.py .
# !cp drive/MyDrive/"Colab Notebooks"/segment_tree.py .
# !cp drive/MyDrive/"Colab Notebooks"/datasampler.py .
# !cp drive/MyDrive/"Colab Notebooks"/critic.py .
# !cp drive/MyDrive/"Colab Notebooks"/model_fc.py .
# !cp drive/MyDrive/"Colab Notebooks"/model_cnn.py .
# !cp drive/MyDrive/"Colab Notebooks"/attacks.py .
# !cp drive/MyDrive/"Colab Notebooks"/linearschedule.py .
# !cp drive/MyDrive/"Colab Notebooks"/datasampler.py .

# %%
# !cp drive/MyDrive/"Colab Notebooks"/test.py .
# !cp drive/MyDrive/"Colab Notebooks"/train.py .

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD GTA GNA --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD GTA GNA
# Out:
# Model number: 210114_27
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 169.61, Test Loss: [116.39867648925781, 114.73057973632812, 115.32795620117187, 155.31549399414064, 117.01365471191406]
# Epoch 1, Train Loss: 118.60, Test Loss: [97.71079483642578, 96.36518231201173, 96.58975600585937, 146.32964230957032, 98.55176473388671]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GNA GTA --useminimax True --adv GNA --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True
# Out:
# Model number: 210114_12
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 143.28, Test Loss: [93.17301960449218, 92.06175319824219, 92.87676716308594, 93.88734553222656, 186.68615078125]
# Epoch 1, Train Loss: 90.40, Test Loss: [81.34503819580078, 80.32271176757813, 80.63819178466797, 81.60786199951171, 219.4189645751953]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GNA GTA --useminimax True --adv GTA --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True
# Out:
# Model number: 210114_14
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 174.83, Test Loss: [129.93782600097657, 128.74205483398438, 132.14468056640624, 135.37598359375, 140.46564921875]
# Epoch 1, Train Loss: 134.82, Test Loss: [117.76080870361328, 116.01711823730469, 125.10134425048828, 127.99821564941406, 128.98290493164063]
# ...

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD GNA GTA --useminimax True --adv GTA --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True
# Out:
# Model number: 210114_25
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 187.08, Test Loss: [137.7638840332031, 136.83892084960937, 138.34393576660156, 141.52527551269532, 146.32987202148436]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GNA GTA --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True
# Out:
# Model number: 210114_15
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 134.11, Test Loss: [87.89312938232422, 86.07710126953125, 95.57277775878906, 102.15693537597656, 215.2897425048828]
# Epoch 1, Train Loss: 84.61, Test Loss: [80.84222412109375, 77.95984155273437, 90.19454846191407, 98.17780085449219, 234.0496770263672]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GNA GTA --useminimax True --adv GNA --eps 0.15 --eps_step 0.05 --k 10
# Out:
# Model number: 210114_17
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 141.31, Test Loss: [95.7904482055664, 94.54230324707031, 93.14367564697265, 95.0196052734375, 196.29857985839843]
# Epoch 1, Train Loss: 86.45, Test Loss: [81.3268998046875, 80.0068884399414, 80.53914764404297, 81.76041955566406, 212.6360781982422]
# Epoch 2, Train Loss: 79.12, Test Loss: [78.41602517089844, 76.97070906982422, 76.4979546875, 78.05278566894532, 233.56305634765624]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GNA GTA --useminimax True --adv RANDOM --eps 0.15 --eps_step 0.05 --k 10
# Out:
# Model number: 210114_19
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 156.38, Test Loss: [109.09883072509766, 108.37722957763673, 106.44924545898438, 108.94180769042968, 150.72834775390626]
# Epoch 1, Train Loss: 111.55, Test Loss: [93.27499187011719, 91.84308430175781, 90.2334702758789, 92.72110308837891, 148.92919885253906]
# Epoch 2, Train Loss: 102.53, Test Loss: [89.24808381347657, 87.1617300415039, 86.248484765625, 89.63393243408203, 151.59528502197264]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD GNA GTA --useminimax True --adv RANDOM --eps 0.15 --eps_step 0.05 --k 10 --epochs 20
# Out:
# Model number: 210114_20
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# Epoch 0, Train Loss: 156.38, Test Loss: [109.09883072509766, 108.37722957763673, 106.44924545898438, 108.94180769042968, 150.72834775390626]
# Epoch 1, Train Loss: 111.55, Test Loss: [93.27499187011719, 91.84308430175781, 90.2334702758789, 92.72110308837891, 148.92919885253906]
# Epoch 2, Train Loss: 102.53, Test Loss: [89.24808381347657, 87.1617300415039, 86.248484765625, 89.63393243408203, 151.59528502197264]
# ...

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD GNA GTA --useminimax True --adv GTA --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True
# Out:
# Model number: 210114_6
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional_tensor.py:876: UserWarning: Argument fill/fillcolor is not supported for Tensor input. Fill value is zero
#   warnings.warn("Argument fill/fillcolor is not supported for Tensor input. Fill value is zero")
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Traceback (most recent call last):
#   File "train.py", line 949, in <module>
#     main()
#   File "train.py", line 908, in main
#     train_loss = train(e)
#   File "train.py", line 574, in train
#     loss.backward()
# ...

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD GNA GTA --useminimax True --adv GNA --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True

# %%
# !python train.py --model fc --metric_valid original --useminimax True --adv LatentA
# Out:
# Model number: 210113_21
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([128, 784])) that is different to the input size (torch.Size([128, 1, 28, 28])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Traceback (most recent call last):
#   File "train.py", line 893, in <module>
#     main()
#   File "train.py", line 852, in main
#     train_loss = train(e)
#   File "train.py", line 328, in train
#     adv = A.LatentA(x, target, args.loss, steps=10, eps=0.08, eps_norm=args.loss)
#   File "/content/attacks.py", line 281, in LatentA
#     loss = delta * loss_2(x, x_star) + loss_2(enc_x_star, z_t)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD
# Out:
# Model number: 210109_6
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 135.90, Test Loss: [91.08889793701172, 89.14593989257813, 89.53079141845703]
# Epoch 1, Train Loss: 86.38, Test Loss: [80.13386025390625, 78.47756401367188, 79.0643338623047]
# Epoch 2, Train Loss: 80.27, Test Loss: [76.73240948486328, 75.00276446533204, 75.51663209228515]
# Epoch 3, Train Loss: 77.18, Test Loss: [74.68758693847656, 73.095988671875, 73.76182100830079]
# Epoch 4, Train Loss: 75.43, Test Loss: [73.8292655883789, 71.88217429199219, 72.67520729980468]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True --usemultiadv True --multiadv FGSM PGD --use_critic True --bs_replaybuffer 640 --best_size=128
# Out:
# Model number: 210109_14
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 154.19, Test Loss: [108.40257938232422, 106.85923785400391, 107.21224039306641]
# Epoch 1, Train Loss: 100.49, Test Loss: [91.93337990722657, 90.10444331054687, 90.99670969238281]
# Epoch 2, Train Loss: 89.41, Test Loss: [85.52394053955078, 83.18630620117187, 83.97818873291016]
# Epoch 3, Train Loss: 85.29, Test Loss: [81.8037708618164, 79.71516623535156, 80.42331719970703]
# Epoch 4, Train Loss: 82.81, Test Loss: [80.80041998291016, 78.67237296142578, 79.64997512207032]
# ...

# %%
# !python train.py --model cnn --metric_valid original FGSM PGD --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10
# Out:
# Model number: 210109_2
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 148.60, Test Loss: [93.7724298461914, 91.8736857421875, 100.7525232421875]
# Epoch 1, Train Loss: 80.98, Test Loss: [77.1002581665039, 74.71303647460938, 92.20409166259766]
# Epoch 2, Train Loss: 70.74, Test Loss: [71.37978850097656, 68.97234615478516, 90.8242595703125]
# Epoch 3, Train Loss: 67.18, Test Loss: [69.47872752685547, 67.00987890625, 89.10437911376953]
# Epoch 4, Train Loss: 65.60, Test Loss: [68.72324145507812, 65.95919506225586, 87.71257634277343]
# Epoch 5, Train Loss: 64.56, Test Loss: [67.66494067382813, 65.14664234619141, 86.70455297851562]
# Epoch 6, Train Loss: 63.81, Test Loss: [67.12939801635743, 64.6443858947754, 89.62862954101563]
# ...

# %%
# !python train.py --model fc --metric_valid original FGSM PGD --useminimax True --adv PGD --eps 0.08 --eps_step 0.05 --k 10

# %%
# dan's testing schedule:
  
  #. test vae                     done
  
  # test test.py                   done by tobias
  # save model                    done
  # save model every save epochs         todo
  # early stop criteria needs reconsidering   yeap
  # save result                   done
  # save hyper parameter              jakob
  # test adversarial training           done
    # test cnn network: might break: ???    done
    # test pgd                   done

  # test the replay buffer            done
  # weight is not normalised?          done
  # wegith should be added            done
 
  # write the new code for multiple adv     3h
    #using attack class based prior and softmax probability inverse of porpotion? annealing to 0     done sort ta
  
  #Friday
  # write the critic                done
  #todo: weighted bias for td error and just loss? 
  #todo: use probabilistic sampling for critic        
  #todo: critic optimizer options
  #todo: weight sampling for importance sampling, weight normalise
  #todo: somehow use td error
  #todo: use the attack type and pass loss and td loss in critic prediction

  #Saturday
  #AL lab week 6     7-12           doing
  #AL lab week 7     12-1           done

  #AL lab week 7     1-10       

  # run parameter search and record performance single adv rb    doing

  # debug critic                                doing
 


  #sunday 
  # test critic                                done
                      1-4
  # model,                                   5-8 work on the vae and adversarial training part
  #                                        9-12 work on replay buffer, game theory, and multi adv and critic
  
  #monday
  #al lab week 7                                  4-7
  #meeting
  #model,             vae                        8-10 
  #model             Adversarial training               10-12
  #model              replay buffer                  12-2

  #Tuesday  
  #AL lab week 8                                  8-2
  #model              replay buffer                  2-4
  # model critic                                  4-6
  #test result                                  test results  6-9
  # write result                                 9-12 
  
  
  #Wednesday
  #al lab week 9                                8-2
  #write result                                  2-6
  #discussion                                   6-8
  #conclusion                                   8-10
  #buffer time

  #Thursday
  #al lab week 9                                8-1                   
  #finalise                                    1-12
  

  #Friday
  
  #submit!!!!! and then back to al labs. week
  #al lab week 10                               4-12

  #saturday sunday
  #week 11-13
  #monday
  #week 14 & catch up

  #1 19 - 1 24 RIAI
  #1 25 - 1 26 catch up AL lab
  #1 27 - 29  al lab exam prep
  #1 30 31 1 2 3 DL
  #2 4 AL lab


  # write tests for comparison with simple criterion like      random attack TE working on it
  
  
                 

  # assume dataset can be splited into interger division using random_split, valid_size parameter
  # training takes too long

# %%
# !ls
# Out:
# attacks.py  linearschedule.py  model_fc.py	    sample_data      test.py
# drive	    model_cnn.py       replay_buffer_v2.py  segment_tree.py  train.py

# %%
# !cp drive/MyDrive/"Colab Notebooks"/test.py .
# !cp drive/MyDrive/"Colab Notebooks"/train.py .

# %%
# !python train.py --model cnn --metric_valid original
# Out:
# ['/content', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions']
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 152.03, Test Loss: [96.3812500366211]
# Epoch 1, Train Loss: 84.65, Test Loss: [78.58398635253906]
# Epoch 2, Train Loss: 74.47, Test Loss: [72.31602971801757]
# Epoch 3, Train Loss: 70.10, Test Loss: [69.77444171142578]
# Epoch 4, Train Loss: 67.93, Test Loss: [68.14889432373047]
# Epoch 5, Train Loss: 66.67, Test Loss: [67.21741160888672]
# Epoch 6, Train Loss: 65.74, Test Loss: [66.74981634521484]
# Epoch 7, Train Loss: 65.05, Test Loss: [66.1114396850586]
# ...

# %%
# !python train.py --model fc --metric_valid original

# %%
# !python train.py --model cnn --metric_valid original
# Out:
# ['/content', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions']
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, Train Loss: 152.03, Test Loss: [96.3812500366211]
# Epoch 1, Train Loss: 84.65, Test Loss: [78.58398635253906]
# Epoch 2, Train Loss: 74.47, Test Loss: [72.31602971801757]
# Epoch 3, Train Loss: 70.10, Test Loss: [69.77444171142578]
# Epoch 4, Train Loss: 67.93, Test Loss: [68.14889432373047]
# Epoch 5, Train Loss: 66.67, Test Loss: [67.21741160888672]
# Epoch 6, Train Loss: 65.74, Test Loss: [66.74981634521484]
# Epoch 7, Train Loss: 65.05, Test Loss: [66.1114396850586]
# ...

# %%
# !python train.py --model fc --metric_valid original --useminimax True --adv FGSM --eps 0.15 --eps_step 0.05 --k 10 --usereplaybuffer True

# %%
# !python train.py --model fc --adv PGD --metric_valid original --useminimax True
# Out:
# ...
# 9920512it [00:00, 9956098.79it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 32768it [00:00, 134572.29it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# ...
# 1654784it [00:00, 2577895.72it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 8192it [00:00, 48290.00it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
# ...
